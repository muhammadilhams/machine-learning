# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadilhams/machine-learning/blob/main/T01_ML_H071201075_Muh_Ilham_Saputra_J.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Muh.Ilham Saputra J
#
# H071201075
#
# Machine Learning

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-d036c706-9459-4c0e-92dd-abc9d64a4eed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d036c706-9459-4c0e-92dd-abc9d64a4eed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls -lha kaggle.json
# Out:
# ls: cannot access 'kaggle.json': No such file or directory

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory

# %%
# !kaggle datasets list -s Iris
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !kaggle datasets download uciml/iris --unzip
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 166, in authenticate
#     self.config_file, self.config_dir))
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %% [markdown]
# # PENGGUNAAN LIBRARY PANDAS DAN NUMPY

# %% [markdown]
# # Latihan 2

# %% [markdown]
# import Library Pandas dan Library Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DATA FRAME

# %% [markdown]
# # Latihan 3

# %% [markdown]
# Panggil file (load dataset) dengan format .csv untuk dataset mengenai bunga Iris yang sudah peserta unduh dari Kaggle, dan akan disimpan di dalam dataframe latihan. Lalu tampilkan 5 baris awal dataset dengan function head()

# %%
latihan = pd.read_csv("/content/Iris.csv")
latihan
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
latihan.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Menelaah data
#
# telaah data ini dilakukan untuk mengetahui tipe data dari setiap kolom, dan deskripsi statistik data

# %% [markdown]
# # Latihan 4

# %%
#menampilkan tipe data dari kolom yang ada pada dataset
latihan.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# # Latihan 5

# %% [markdown]
# tipe data pada kolom di dataset

# %%
#kolom id
(latihan["Id"].dtypes)
# Out:
# dtype('int64')

# %%
#kolom SepalLengthCm
(latihan["SepalLengthCm"].dtypes)
# Out:
# dtype('float64')

# %%
#kolom Species
(latihan["Species"].dtypes)
# Out:
# dtype('O')

# %% [markdown]
# 1. kolom id bertipe data integer
# 2. kolom SepalLengthCm bertipe data float
# 3. kolom species bertipe data object

# %% [markdown]
# # latihan 6

# %% [markdown]
# menghitung ukuran dari dataset dengan method function

# %%
latihan.shape
# Out:
# (150, 6)

# %% [markdown]
# dengan menggunakan method function diketahui dimensi dari dataframe pada dataset jumlah baris dan kolom dari dataset secara berurutan adalah 150 dan 6

# %% [markdown]
# # Latihan 7

# %% [markdown]
# jumlah baris dan kolom pada dataset

# %%
#jumlah baris = 150
#jumlah kolom = 6

# %% [markdown]
# # Latihan 8
# menampilkan data yang berisi kolom id dan species dalam bentuk dataframe

# %%
selected = latihan[["Id","Species"]]
pd.DataFrame(selected)
latihan
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Latihan 9
# menampilkan data dengan dataframe, dan data yang ditampilkan adalah data pada baris dengan indeks 0 sampai dengan indeks 9

# %%
latihan.iloc[:10]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# # Latihan 10
# menampilkan data hanya kolom Id dan kolom Species dengan dataframe,(data pada baris dengan indeks 11 sampai dengan indeks 15)

# %%
selected = latihan[["Id","Species"]]
selected.iloc[11:16]
# Out:
#     Id      Species
# 11  12  Iris-setosa
# 12  13  Iris-setosa
# 13  14  Iris-setosa
# 14  15  Iris-setosa
# 15  16  Iris-setosa

# %% [markdown]
# # latihan 11
# menampilkan data pada 8 (delapan) baris pertama dari dataset, dengan dataframe.

# %%
latihan.head(8)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa

# %% [markdown]
# # latihan 12
# menampilkan data pada tiga baris terakhir dari dataset dengan dataframe

# %%
latihan.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# Deskripsi Statistik Data

# %% [markdown]
# # latihan 13
# menghitung korelasi dataset dengan method function

# %%
latihan.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# # latihan 14
# kesimpulan dari perhitungan korelasi pada **latihan 13**

# %%
# 1. PetalLengthCm dan PetalWidthCm memiliki korelasi yang tinggi (nilai 0,96)
# 2. PetalWidthCm dan SepalLengthCm memiliki korelasi yang baik (nilai 0,82)
# 3. PetalLenghtCm dan SepalLenghtCm memiliki korelasi yang baik (nilai 0,87)

# %% [markdown]
# # Latihan 15
# mengitung korelasi untuk PetalLengthCm, PetalWidthCm

# %%
selected2 = latihan[["PetalLengthCm", "PetalWidthCm"]]
selected2.corr()
# Out:
#                PetalLengthCm  PetalWidthCm
# PetalLengthCm       1.000000      0.962757
# PetalWidthCm        0.962757      1.000000

# %% [markdown]
# # latihan 16
# menggunakan metode describe untuk komputasi statistik

# %%
latihan.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Latihan 17
# menggunakan method describe pada dataset yang sudah di load untuk data bertype objek

# %%
latihan.describe(include = "object")
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %% [markdown]
# # latihan 18
# menggunakan method describe pada dataset yang sudah di load untuk semua type data (continous variabel dan type object).

# %%
latihan.describe(include = "all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %% [markdown]
# # latihan 19
# menghitung nilai mean(rerata)

# %%
latihan.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %% [markdown]
# # Latihan 20
# mean untuk kolom PetalLengthCm

# %%
latihan["PetalLengthCm"].mean()
# Out:
# 3.758666666666666

# %% [markdown]
# # latihan 21
# nilai minimal untuk kolom SepalWidthCm.

# %%
latihan["SepalWidthCm"].min()
# Out:
# 2.0

# %% [markdown]
# # latihan 22
# menghitung mean dari dataset untuk kolom SepalLengthCm per Species dengan menggunakan metode groupby.

# %%
latihan.groupby("Species")["SepalLengthCm"].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %% [markdown]
# Method Value Count

# %% [markdown]
# # latihan 23
# frekuensi pada kolom 'Species' dengan menggunakan metode value_counts().

# %%
latihan["Species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # latihan 24
# frekuensi pada kolom 'Species' dengan menggunakan metode value_counts() dalam bentuk dataframe

# %%
dataframe = latihan["Species"].value_counts()
show = pd.DataFrame(dataframe)
show
# Out:
#                  Species
# Iris-setosa           50
# Iris-versicolor       50
# Iris-virginica        50

# %% [markdown]
# # latihan 25
# frekuensi pada kolom 'PetalLenghCm' dengan menggunakan metode value_counts() dan dalam bentuk dataframe.

# %%
dataframe = latihan["PetalLengthCm"].value_counts()
show = pd.DataFrame(dataframe)
show
# Out:
#      PetalLengthCm
# 1.5             14
# 1.4             12
# 5.1              8
# 4.5              8
# 1.6              7
# 1.3              7
# 5.6              6
# 4.7              5
# 4.9              5
# 4.0              5
# 4.2              4
# 5.0              4
# 4.4              4
# 4.8              4
# 1.7              4
# 3.9              3
# 4.6              3
# 5.7              3
# 4.1              3
# 5.5              3
# 6.1              3
# 5.8              3
# 3.3              2
# 5.4              2
# 6.7              2
# 5.3              2
# 5.9              2
# 6.0              2
# 1.2              2
# 4.3              2
# 1.9              2
# 3.5              2
# 5.2              2
# 3.0              1
# 1.1              1
# 3.7              1
# 3.8              1
# 6.6              1
# 6.3              1
# 1.0              1
# 6.9              1
# 3.6              1
# 6.4              1
